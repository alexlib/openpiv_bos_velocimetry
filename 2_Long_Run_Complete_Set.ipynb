# %% [markdown]
# # OpenPIV BOS Velocimetry
#
# PIV - particle image velocimetry
# BOS - background oriented schlieren
#
# ## Data credit: Gary Settles, PSU
# See his [paper](https://doi.org/10.3929/ethz-b-000279222)
#
# ## OpenPIV part credit: Alex Liberzon, TAU
# read about software used here:
# [OpenPIV](http://www.openpiv.net) and [PIVPy](http://github.com/alexlib/pivpy)
#
#
# ## Short description of the process:
#
# 2. Displacement to density gradients - using PIVPy we convert it to density gradient fields
# 3. Second OpenPIV round on density gradients - density gradient patches to displacement fields, sort of velocimetry
# 4. Second PIVPy round - visualization of the BOS velocimetry data

# %% [markdown]
# # Run the following notebooks:

# %%
# %run colab_openpiv_windef_run.ipynb
# %run pivpy_load_data.ipynb
# %run openpiv_windef_density.ipynb
# %run pivpy_load_density.ipynb

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5a409ffc-4365-43ea-9d49-425c249ee983' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
