# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting git+https://github.com/alexlib/pivpy (from -r ./requirements.txt (line 2))
#   Cloning https://github.com/alexlib/pivpy to /tmp/pip-req-build-5yjyqe3w
#   Resolved https://github.com/alexlib/pivpy to commit 7b245f084b217dab7b08685488d7c77f53f0ea9c
# Collecting openpiv
#   Downloading OpenPIV-0.23.8-py3-none-any.whl (22.3 MB)
# Collecting watermark
#   Downloading watermark-2.3.0-py2.py3-none-any.whl (7.2 kB)
# Requirement already satisfied: matplotlib>=3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from openpiv->-r ./requirements.txt (line 1)) (3.5.1)
# Requirement already satisfied: scipy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from openpiv->-r ./requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: pytest in /shared-libs/python3.9/py/lib/python3.9/site-packages (from openpiv->-r ./requirements.txt (line 1)) (7.0.1)
# Collecting imageio
#   Downloading imageio-2.16.0-py3-none-any.whl (3.3 MB)
# Requirement already satisfied: numpy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from openpiv->-r ./requirements.txt (line 1)) (1.22.2)
# Collecting natsort
#   Downloading natsort-8.1.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from openpiv->-r ./requirements.txt (line 1)) (4.62.3)
# Collecting scikit-image
#   Downloading scikit_image-0.19.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
# Collecting GitPython
#   Downloading GitPython-3.1.26-py3-none-any.whl (180 kB)
# Collecting xarray
#   Downloading xarray-0.21.1-py3-none-any.whl (865 kB)
# Collecting readim
#   Downloading ReadIM-0.8.4.tar.gz (8.1 MB)
# Requirement already satisfied: ipython in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from watermark->-r ./requirements.txt (line 3)) (7.31.1)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib>=3->openpiv->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib>=3->openpiv->-r ./requirements.txt (line 1)) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib>=3->openpiv->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3->openpiv->-r ./requirements.txt (line 1)) (4.29.1)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3->openpiv->-r ./requirements.txt (line 1)) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3->openpiv->-r ./requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3->openpiv->-r ./requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3->openpiv->-r ./requirements.txt (line 1)) (1.16.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: backcall in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython->watermark->-r ./requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython->watermark->-r ./requirements.txt (line 3)) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython->watermark->-r ./requirements.txt (line 3)) (3.0.28)
# Requirement already satisfied: pickleshare in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython->watermark->-r ./requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython->watermark->-r ./requirements.txt (line 3)) (0.17.2)
# Requirement already satisfied: setuptools>=18.5 in /root/venv/lib/python3.9/site-packages (from ipython->watermark->-r ./requirements.txt (line 3)) (57.4.0)
# Requirement already satisfied: pygments in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython->watermark->-r ./requirements.txt (line 3)) (2.11.2)
# Requirement already satisfied: decorator in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython->watermark->-r ./requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython->watermark->-r ./requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython->watermark->-r ./requirements.txt (line 3)) (4.3.3)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jedi>=0.16->ipython->watermark->-r ./requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pexpect>4.3->ipython->watermark->-r ./requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->watermark->-r ./requirements.txt (line 3)) (0.2.5)
# Requirement already satisfied: ipython-genutils in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from traitlets>=4.2->ipython->watermark->-r ./requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pytest->openpiv->-r ./requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: tomli>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pytest->openpiv->-r ./requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: iniconfig in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pytest->openpiv->-r ./requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pytest->openpiv->-r ./requirements.txt (line 1)) (21.4.0)
# Requirement already satisfied: py>=1.8.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pytest->openpiv->-r ./requirements.txt (line 1)) (1.11.0)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.2.9-py3-none-any.whl (180 kB)
# Collecting networkx>=2.2
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.2.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
# Requirement already satisfied: pandas>=1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from xarray->pivpy==0.0.9rc0->-r ./requirements.txt (line 2)) (1.2.5)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=1.1->xarray->pivpy==0.0.9rc0->-r ./requirements.txt (line 2)) (2021.3)
# Building wheels for collected packages: pivpy, readim
#   Building wheel for pivpy (setup.py): started
#   Building wheel for pivpy (setup.py): finished with status 'done'
#   Created wheel for pivpy: filename=pivpy-0.0.9rc0-py3-none-any.whl size=3906735 sha256=1efcea744e81c86f74406bb5d1425de37c03d1e4e85d8176e5115396d2dae502
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9wbsgugh/wheels/58/7c/71/47e54549157085ca182284824faf65230e5d4043ff80a84bfd
#   Building wheel for readim (setup.py): started
#   Building wheel for readim (setup.py): finished with status 'done'
#   Created wheel for readim: filename=ReadIM-0.8.4-cp39-cp39-linux_x86_64.whl size=8171443 sha256=c96dfc3269542bb58791931844ba4b2772677fabb2caa431b14c6390295d1b1d
#   Stored in directory: /root/.cache/pip/wheels/a4/87/51/cbcc8a07059aa09896b8b80e1396965c585af67638033711c1
# Successfully built pivpy readim
# Installing collected packages: smmap, tifffile, PyWavelets, networkx, imageio, gitdb, xarray, watermark, scikit-image, readim, natsort, GitPython, pivpy, openpiv
# Successfully installed GitPython-3.1.26 PyWavelets-1.2.0 gitdb-4.0.9 imageio-2.16.0 natsort-8.1.0 networkx-2.6.3 openpiv-0.23.8 pivpy-0.0.9rc0 readim-0.8.4 scikit-image-0.19.2 smmap-5.0.0 tifffile-2022.2.9 watermark-2.3.0 xarray-0.21.1
#   Running command git clone -q https://github.com/alexlib/pivpy /tmp/pip-req-build-5yjyqe3w
# WARNING: You are using pip version 21.2.3; however, version 22.0.3 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5a409ffc-4365-43ea-9d49-425c249ee983' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
